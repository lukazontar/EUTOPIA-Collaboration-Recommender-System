# %% [markdown]
# # Which authors tends to be more collaborative with external institutions?
#
# In this script we will try to answer the question of which authors tends to be more collaborative with EUTOPIA institutions.

# %%
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pymc as pm
import seaborn as sns
from box import Box
from google.cloud import bigquery
from scipy.stats import percentileofscore

# %%
# -------------------- GLOBAL VARIABLES --------------------
PATH_TO_CONFIG_FILE = '../config.yml'

# -------------------- LOAD CONFIGURATION --------------------
# Load the configuration file
config = Box.from_yaml(filename=PATH_TO_CONFIG_FILE)
# Initialize a BigQuery client
client = bigquery.Client(project=config.GCP.PROJECT_ID)
# Set the BigQuery dataset schema
schema = config.GCP.READ_SCHEMA
# Set numpy random seed
np.random.seed(config.RANDOM_SEED)

# %% [markdown]
# ## Data preparation
# After loading the general configuration, we will prepare the data from BigQuery:
# 1. Count the number of publications and external collaborations for each author.
# 2. Calculate the proportion of external collaborations for each author.
# 3. Filter out authors from non-EUTOPIA institutions and authors with zero publications or zero collaborations.
# 4. Clip the collaboration rate to avoid issues with the Beta distribution in the Bayesian model.

# %%
# Read data via BigQuery
query = f"""
SELECT
  AUTHOR_SID,
  COUNT(ARTICLE_SID)                                                AS PUBLICATIONS,
  COUNT(DISTINCT IF(IS_EXTERNAL_COLLABORATION, ARTICLE_SID, NULL))  AS EXTERNAL_COLLABORATIONS
FROM
    {schema}.FCT_COLLABORATION
WHERE IS_ARTICLE_RELEVANT
GROUP BY AUTHOR_SID
"""
df = client.query(query).to_dataframe()

# We need to calculate the proportion of external collaborations for each author
df['COLLABORATION_RATE'] = df['EXTERNAL_COLLABORATIONS'] / df['PUBLICATIONS']

# Handle zero publications or zero collaborations to avoid issues with the Beta distribution
df = df[(df['PUBLICATIONS'] > 0) & (df['EXTERNAL_COLLABORATIONS'] >= 0)]
# Filter out outliers with extremely low number of publications
df = df[(df['PUBLICATIONS'] >= 10)]
# Clip the collaboration rate to avoid issues with the Beta distribution
df['COLLABORATION_RATE'] = np.clip(a=df['COLLABORATION_RATE'],
                                   a_min=1e-6,
                                   a_max=1 - 1e-6)

# %%
# Visualize the distributions of publications and external collaborations in side-by-side histograms
# 1. Distribution of Publications per Author
fig, (plt1, plt2) = plt.subplots(1, 2, figsize=(16, 6))
sns.histplot(df[df['PUBLICATIONS'] > 50]['PUBLICATIONS'], bins=30, kde=True, ax=plt1)
plt1.set_title('Distribution of Publications per Author')
plt1.set_xlabel('Number of Publications')
plt1.set_ylabel('Frequency')
# 2. Distribution of External Collaborations per Author
sns.histplot(df[df['PUBLICATIONS'] > 50]['EXTERNAL_COLLABORATIONS'], bins=30, kde=True, ax=plt2)
plt2.set_title('Distribution of External Collaborations per Author')
plt2.set_xlabel('Number of External Collaborations')
plt2.set_ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Bayesian model
#
# We will define a simple Bayesian model to describe the collaboration rate of authors with EUTOPIA institutions. Using Bayesian inference, we estimate the parameters (`alpha` and `beta`) of a Beta distribution that best describe the observed collaboration rates of authors.
#
# **Prior:** We use HalfNormal priors for the parameters `alpha` and `beta`. The HalfNormal distribution is a suitable choice for positive real-valued parameters because it only allows positive values. We set the standard deviation of the HalfNormal priors to 10, which is a relatively uninformative prior and hence not too constraining.
#
# **Data likelihood:** We model the observed collaboration rates as a Beta distribution with parameters `alpha` and `beta`. Beta distribution is a suitable choice for modeling the collaboration rate because it is a continuous distribution that is constrained between 0 and 1. The parameters `alpha` and `beta` of the Beta distribution are positive real numbers that control the shape of the distribution.

# %%
# Define the Bayesian model using PyMC
with pm.Model() as model:
    # Priors influenced by the number of publications
    alpha = pm.HalfNormal(name='alpha',
                          sigma=10)
    beta = pm.HalfNormal(name='beta',
                         sigma=10)

    # Deterministic variable for mean collaboration rate
    theta = pm.Deterministic(name='theta',
                             var=alpha / (alpha + beta))

    # Likelihood (sampling distribution) of observations
    y_obs = pm.Beta(name='y_obs',
                    alpha=alpha,
                    beta=beta,
                    observed=df['COLLABORATION_RATE'])

    # Inference
    trace = pm.sample(draws=2000,
                      tune=1000,
                      cores=4,
                      target_accept=0.95,
                      return_inferencedata=True,
                      progressbar=True,
                      random_seed=config.RANDOM_SEED)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [alpha, beta]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 37 seconds.

# %% [markdown]
# ## Analysis: author collaborativeness with external institutions
#
# The expected value of the Beta distribution is given by `alpha / (alpha + beta)`, which represents the central tendency of the collaboration rates.
# Then from the posterior distributions of `alpha` and `beta`, we can calculate the expected value of the collaboration rate, `theta`. This expected value represents the central tendency of the collaboration rates across all authors.
# We compare individual authors' collaboration rates to the inferred mean collaboration rate (`theta_mean`). Authors with collaboration rates higher than this mean are considered to be **more collaborative with external institutions**.
#
# Lastly, we calculate the percentile of each author's collaboration rate based on the posterior samples. This percentile represents the **author's relative position** compared to other authors in terms of collaboration rates.

# %% [markdown]
# ### Analyze sampling traces and posterior distributions

# %%
# Summarize the trace
summary = az.summary(trace, hdi_prob=0.95)
print(summary)

# Visualize the trace and posterior distributions
az.plot_trace(trace)
az.plot_autocorr(trace)
az.plot_posterior(trace)
# Out:
#         mean     sd  hdi_2.5%  hdi_97.5%  mcse_mean  mcse_sd  ess_bulk  \
# alpha  0.826  0.013     0.801      0.851        0.0      0.0    3732.0
# beta   0.239  0.003     0.234      0.244        0.0      0.0    3797.0
# theta  0.776  0.003     0.771      0.781        0.0      0.0    5510.0
#
#        ess_tail  r_hat
# alpha    4547.0    1.0
# beta     4612.0    1.0
# theta    5250.0    1.0
# array([<Axes: title={'center': 'alpha'}>,
#        <Axes: title={'center': 'beta'}>,
#        <Axes: title={'center': 'theta'}>], dtype=object)

# %%
# Extract the mean collaboration rate from the posterior distribution 
theta_mean = summary.loc['theta', 'mean']

# Sample collaboration rates from the posterior distribution
posterior_samples = trace.posterior.stack(samples=("chain", "draw"))
alpha_samples = posterior_samples['alpha'].values
beta_samples = posterior_samples['beta'].values

# Calculate the collaboration rate percentiles for each author
collaboration_rate_samples = np.random.beta(alpha_samples, beta_samples)
collaboration_rate_samples_sorted = np.sort(collaboration_rate_samples, axis=0)
percentiles = np.array([percentileofscore(collaboration_rate_samples_sorted, x) for x in df['COLLABORATION_RATE']])
df['COLLABORATION_RATE_PERCENTILE'] = percentiles

# Get more collaborative authors
df['IS_AUTHOR_MORE_COLLABORATIVE'] = df['COLLABORATION_RATE'] > theta_mean

# %%
import pandas as pd

# Query the author full names from DIM_AUTHOR table from BigQuery
query = f"""
SELECT
    A.AUTHOR_SID,
    A.AUTHOR_FULL_NAME,
    STRING_AGG(DISTINCT F.INSTITUTION_SID) AS INSTITUTIONS
FROM
    {schema}.FCT_COLLABORATION F
INNER JOIN 
    {schema}.DIM_AUTHOR A USING(AUTHOR_SID)
WHERE F.IS_ARTICLE_RELEVANT
GROUP BY A.AUTHOR_SID, A.AUTHOR_FULL_NAME
"""
# Query the author full names
df_author = client.query(query).to_dataframe()

# Merge the top authors with their full names
authors = df.merge(df_author, on='AUTHOR_SID')
pd.set_option('display.max_rows', None)
# Only show authors working on institution UNI_LJ
authors[authors['INSTITUTIONS'].str.contains('UNI_LJ')].sort_values(by='COLLABORATION_RATE_PERCENTILE',
                                                                    ascending=False).head(100)
# Out:
#                             AUTHOR_SID  PUBLICATIONS  EXTERNAL_COLLABORATIONS  \
# 3279  e40fd30336b933e33d025af2c7602584            10                       10
# 6549  7f223fcef7c4c49ccf719d50f660b727            11                       11
# 5162  38e5e08ad7d6b016a4925000f3060ac8            14                       14
# 8105  559b8b2c410bd001b221c5208de2b8b1            12                       12
# 8468  a31e9e0c8b3dd1424793c929d4a19921            11                       11
# 2309  e0a8410c22f0bc3583c538db5ae5ec87            15                       15
# 2212  4422633f644b5b37f67939403b65dbce            10                       10
# 5600  1ea25a3de606684ab46e7f0f67ba43e2            17                       17
# 4884  7b0a0c843f3705473bbe68f7858623f2            41                       41
# 5867  ae511fe7d6e6c51f9c70afe1c8474525            18                       18
# 4706  ead7875aee84fdae9b123bad52f1d938            10                       10
# 6236  cbf07da7d08fe12c9dfbc31a26da76bc            12                       12
# 580   3ee9b8baf4600543dc316123c91f1901            11                       11
# 4081  0089fb0d2d104a85df920bba051e15e3            10                       10
# 2426  d9120803dc18ba720b4e7611a4a88149            11                       11
# 210   ad8bbaaa79287caef713ba6d93d8fa9b            45                       45
# 7243  fde6bc5b2d35cfc20c0dff7fc6d29d59            11                       11
# 2978  f9e2df536c47758081c5900a9e862c91            29                       28
# 1455  a5d486cdb31b85ef749782850f3bdb39            56                       54
# 2170  c4345a1d5b6eb7a12344a8c03cbe1faf            25                       24
# 5368  2422fd18542283d6d9dd37b9ae8f3952            24                       23
# 2767  7c6895e5ab9efc3e837ea1a9bf9cdc9f            23                       22
# 4401  1e00b69dc1a228b7711914faa0dc8a32            21                       20
# 3075  0b954baf86ee02fa23a94a70f1f89470            21                       20
# 1312  8fd1817760e737b25c52910743f62fd6            20                       19
# 1444  bdba12151bd2bdc98b2f4fd5c1c2c46a            20                       19
# 559   2bd5c4914277f0a7201274725cc170bb            19                       18
# 5     7f7af53ad78d44795ea614ad297c8587            17                       16
# 382   3a0722f34e1b129d8795b9ab27f97952            17                       16
# 1518  5118837900e6d576cd1bb5ddadb077b2            17                       16
# 6194  b2f7f7c025458bdb9c26dac735a29f1b            33                       31
# 1989  fb86588a2f87823a501319621dcd0a04            32                       30
# 5261  57db808e6be783e7c2e4ec64f9553618            15                       14
# 6566  7510fcec7b9743a996f72ac37236c9fe            15                       14
# 6784  a6a4f7a1cc61704326aabd91116372a4            15                       14
# 2657  cec20dd1dcf87061eec13a4c62574d90            45                       42
# 6395  1e005da45ba862df56af9901837a2323            14                       13
# 4736  87319833cf095a5053a66d873426bf48            14                       13
# 2837  a2953b2df4bad33ade03cf61ee829f99            14                       13
# 2441  76c29db2f36bcd9ec40d1cb9f5c53782            14                       13
# 8511  6b827b8d0b1dcd05b3e9f72acc7f3ec4            13                       12
# 3139  ab153bd85de31a9ea054365d0d943cbe            12                       11
# 5808  4bc6935f2f8b44e6606047989a5ec64e            12                       11
# 5657  e876e9cfad3be1be5964e439fecf9df3            12                       11
# 7096  363582b7c004ac0c077de6e4a94ec22b            12                       11
# 602   70fab9cbb51f6881003cb3e6fe3270e8            12                       11
# 6226  e1b64d56000db5089e45352d6b6486ff            11                       10
# 5114  3ba010c1d808c9366835ea54d4dc0342            11                       10
# 4428  92757f6c9dc122823beeaf55458c80e7            11                       10
# 8436  609ce8dfa6c4540e182da7e04230e9c9            11                       10
# 7866  6a84b8a80065114645851ee941c14ec2            11                       10
# 4831  9cae1b69abbd2eca6fbab6cf378561be            11                       10
# 5248  522a2c111d183a26a4def9c274b4e194            21                       19
# 5265  6b0abf40f47c6427777c5595f489494b            10                        9
# 6470  0fec7146b58af4dc4ec92ac502a9f562            10                        9
# 5232  e7a6f7b13ece75f2bc7793e5616a068b            10                        9
# 4067  2821d600878aa718a580f9725d68b672            10                        9
# 3902  e3deb2103f70ec4170acf9f628b73838            30                       27
# 7414  d464ead51953a7833f35f1fcdf0987c0            10                        9
# 3702  08ad0e36a15399216667d529204987c4            10                        9
# 6048  f511fe5422ffa4d745100e50de797c62            10                        9
# 3639  cf809f3a8ef7dec83b118f55739a0a9e            10                        9
# 5092  64ef51310e1a5c757ea447c97bcd594e            10                        9
# 2673  9187e2703a84efbb4dd452f894a23f35            10                        9
# 6585  7a733a9d10a8c2434928678ab4bb2223            10                        9
# 7503  9ea46108624449e03e8bce58b2fabbd2            10                        9
# 6909  1495a4abe1d7e158937af4b062d9752e            19                       17
# 5123  2a445e42650ecb4a6320d715ccd840c7            19                       17
# 1950  bc5c15fe662691706d2d108aedb7b62d            18                       16
# 3180  363c5cc28771def3bf34a69fd01e8976            26                       23
# 4075  64d2bfd8ff2828e64ec95db0199c9b16            26                       23
# 6656  d52e2b3f70e1f562705403133e96aa28            25                       22
# 7371  165dc93423c52beb8f3ec7e24bed3eb4            16                       14
# 2742  fc70ceafb94a499ca2b7a56541ebc4e3            15                       13
# 8342  db721e9d534f524a5476a3cd77e74b08            15                       13
# 5899  9c8e9331f92f9a6f094c44acd27045d9            22                       19
# 310   68dcc82e5b99e0be1b27eb245f18c377            43                       37
# 5885  3c10183793241941146be4ddf9b51149            14                       12
# 6181  274eb5e57ebafc7e917be74d895ef6fb            14                       12
# 5822  33e168cc757db6d08d16d477f2c00ab4            14                       12
# 3822  f2d009c2a7967ba4463ad5c10010ebad            14                       12
# 3776  1bcb8665fa8987c21ef4f36c0b9f64f5            27                       23
# 393   44bd4b57086e2aca02907802cc91dfa7            27                       23
# 420   399967837ec0d0c263125e950bcbecf9            20                       17
# 8004  4436c2784c4d86eb59ea0f79348daf53            13                       11
# 4538  159a34d833293347a86767fa6f0c4641            13                       11
# 3659  7529fde8595490bf23c0a05fe96f50fa            13                       11
# 262   a6993cd24f648f9c27ed06031c784271            26                       22
# 300   aa59da6c862c62067d2ca6ca62281a94            13                       11
# 6537  6a289c0599987cf537f80560fb50350a            13                       11
# 3093  70dd729f44f76b2e6b59dd7aeb86421b            13                       11
# 7881  7179c4d23e78e1939c287635a69d8605            26                       22
# 8012  ffe1eedfdb29269b989312dc3a7d3875            13                       11
# 4866  d05439e49c4f67255f83d2d7a803ed94            13                       11
# 6634  f31814ca728306f12d0106216df1edff            19                       16
# 2834  a8c11c1446892048fec37b1c86c3be70            19                       16
# 644   de8b516602c026764322e5b349b58820            18                       15
# 426   15499d5b349f723674dea1bdbd378c50            12                       10
# 6467  ab88ce60d94241bf7b00da7e077ac049            18                       15
# 8104  26715f1d53b4107cb7018a6cd4f8093b            12                       10
#
#       COLLABORATION_RATE  COLLABORATION_RATE_PERCENTILE  \
# 3279            0.999999                        96.4375
# 6549            0.999999                        96.4375
# 5162            0.999999                        96.4375
# 8105            0.999999                        96.4375
# 8468            0.999999                        96.4375
# 2309            0.999999                        96.4375
# 2212            0.999999                        96.4375
# 5600            0.999999                        96.4375
# 4884            0.999999                        96.4375
# 5867            0.999999                        96.4375
# 4706            0.999999                        96.4375
# 6236            0.999999                        96.4375
# 580             0.999999                        96.4375
# 4081            0.999999                        96.4375
# 2426            0.999999                        96.4375
# 210             0.999999                        96.4375
# 7243            0.999999                        96.4375
# 2978            0.965517                        58.4125
# 1455            0.964286                        57.9875
# 2170                0.96                        56.7125
# 5368            0.958333                        56.4375
# 2767            0.956522                        56.0375
# 4401            0.952381                        54.8625
# 3075            0.952381                        54.8625
# 1312                0.95                        54.3500
# 1444                0.95                        54.3500
# 559             0.947368                        53.8000
# 5               0.941176                        52.6375
# 382             0.941176                        52.6375
# 1518            0.941176                        52.6375
# 6194            0.939394                        52.2125
# 1989              0.9375                        51.7750
# 5261            0.933333                        51.0125
# 6566            0.933333                        51.0125
# 6784            0.933333                        51.0125
# 2657            0.933333                        51.0125
# 6395            0.928571                        50.2375
# 4736            0.928571                        50.2375
# 2837            0.928571                        50.2375
# 2441            0.928571                        50.2375
# 8511            0.923077                        49.2000
# 3139            0.916667                        48.2750
# 5808            0.916667                        48.2750
# 5657            0.916667                        48.2750
# 7096            0.916667                        48.2750
# 602             0.916667                        48.2750
# 6226            0.909091                        47.2500
# 5114            0.909091                        47.2500
# 4428            0.909091                        47.2500
# 8436            0.909091                        47.2500
# 7866            0.909091                        47.2500
# 4831            0.909091                        47.2500
# 5248            0.904762                        46.5875
# 5265                 0.9                        46.0125
# 6470                 0.9                        46.0125
# 5232                 0.9                        46.0125
# 4067                 0.9                        46.0125
# 3902                 0.9                        46.0125
# 7414                 0.9                        46.0125
# 3702                 0.9                        46.0125
# 6048                 0.9                        46.0125
# 3639                 0.9                        46.0125
# 5092                 0.9                        46.0125
# 2673                 0.9                        46.0125
# 6585                 0.9                        46.0125
# 7503                 0.9                        46.0125
# 6909            0.894737                        45.3125
# 5123            0.894737                        45.3125
# 1950            0.888889                        44.5625
# 3180            0.884615                        44.0375
# 4075            0.884615                        44.0375
# 6656                0.88                        43.4875
# 7371               0.875                        42.9625
# 2742            0.866667                        41.9500
# 8342            0.866667                        41.9500
# 5899            0.863636                        41.6000
# 310             0.860465                        41.2250
# 5885            0.857143                        40.9000
# 6181            0.857143                        40.9000
# 5822            0.857143                        40.9000
# 3822            0.857143                        40.9000
# 3776            0.851852                        40.3000
# 393             0.851852                        40.3000
# 420                 0.85                        40.0750
# 8004            0.846154                        39.7750
# 4538            0.846154                        39.7750
# 3659            0.846154                        39.7750
# 262             0.846154                        39.7750
# 300             0.846154                        39.7750
# 6537            0.846154                        39.7750
# 3093            0.846154                        39.7750
# 7881            0.846154                        39.7750
# 8012            0.846154                        39.7750
# 4866            0.846154                        39.7750
# 6634            0.842105                        39.4375
# 2834            0.842105                        39.4375
# 644             0.833333                        38.7750
# 426             0.833333                        38.7750
# 6467            0.833333                        38.7750
# 8104            0.833333                        38.7750
#
#       IS_AUTHOR_MORE_COLLABORATIVE          AUTHOR_FULL_NAME  \
# 3279                          True              Jernej Jakše
# 6549                          True             Anja Oštrbenk
# 5162                          True               Miha Krofel
# 8105                          True           Dušan D. Repovš
# 8468                          True            Katarina Čufar
# 2309                          True           Boštjan Genorio
# 2212                          True                 J. Reščič
# 5600                          True               Klemen Dovc
# 4884                          True              Maja Cemazar
# 5867                          True                Cene Fišer
# 4706                          True       V. Adrian Parsegian
# 6236                          True           Matija Jezeršek
# 580                           True          Igor B. Mekjavic
# 4081                          True               Matej Černe
# 2426                          True              Grega Repovs
# 210                           True            Mirjana Liovic
# 7243                          True              Robert Zorec
# 2978                          True             Tomaž Zwitter
# 1455                          True             Bengt Winblad
# 2170                          True             Jean Bousquet
# 5368                          True               Tadej Avcin
# 2767                          True            Natasa Bratina
# 4401                          True             Tadej Debevec
# 3075                          True                    Yan Li
# 1312                          True          Alberto Morgante
# 1444                          True         Nataša Fidler Mis
# 559                           True             Sibylle Loibl
# 5                             True             Gregor Traven
# 382                           True             Klemen Bohinc
# 1518                          True                Cene Fišer
# 6194                          True                   Gang Wu
# 1989                          True                  Yang Liu
# 5261                          True            Marko Anderluh
# 6566                          True          Eleonora Aronica
# 6784                          True         Laura Fratiglioni
# 2657                          True           Tadej Battelino
# 6395                          True          Miroslav Svoboda
# 4736                          True         Damijan Miklavcic
# 2837                          True              Dušan Repovš
# 2441                          True       Siranoush Manoukian
# 8511                          True                   Bor Kos
# 3139                          True              Paolo Radice
# 5808                          True                    L. Kos
# 5657                          True              Franc Perdih
# 7096                          True         Gianfranco Parati
# 602                           True           Maja Zagmajster
# 6226                          True                Natasa Tul
# 5114                          True         Yu. V. Kalyuzhnyi
# 4428                          True               Primož Oven
# 8436                          True    Andreja Trojner Bregar
# 7866                          True          Aleksandra Golob
# 4831                          True               Gregor Mali
# 5248                          True         Maria Eriksdotter
# 5265                          True               Simon Čopar
# 6470                          True            Damjana Drobne
# 5232                          True            Cene Gostinčar
# 4067                          True           Goran Petrovski
# 3902                          True          Isaac Blickstein
# 7414                          True          Ingemar Kåreholt
# 3702                          True             Nataša Toplak
# 6048                          True             Katja Goričar
# 3639                          True             Bojana Beovic
# 5092                          True               Špela Borko
# 2673                          True             Miran Mozetič
# 6585                          True                J. Kovačič
# 7503                          True    Joaquin Martinez-Lopez
# 6909                          True           Nedjeljka Žagar
# 5123                          True                Nace Zidar
# 1950                          True               Martin Šala
# 3180                          True           Tihomir Tomašič
# 4075                          True                 Lars Lind
# 6656                          True         Damijan Miklavčič
# 7371                          True               Saša Čučnik
# 2742                          True             Anja Klančnik
# 8342                          True              Tomaz Kocjan
# 5899                          True              Matjaž Homan
# 310                           True                 Janez Kos
# 5885                          True              Andrej Starc
# 6181                          True                Boris Sket
# 5822                          True            Nataša Bratina
# 3822                          True            Mirjana Liovic
# 3776                          True            Marko Anderluh
# 393                           True        Sonja Smole Možina
# 420                           True           Stanislav Gobec
# 8004                          True             Vedran Hadžić
# 4538                          True            Albano Cossaro
# 3659                          True           Thomas A. Nagel
# 262                           True              Izidor Sosič
# 300                           True             Matej Drobnič
# 6537                          True      Tatjana Avšič-Županc
# 3093                          True             Helena Lenasi
# 7881                          True               Vita Dolzan
# 8012                          True  Nikolaos S. Papageorgiou
# 4866                          True               Miha Krofel
# 6634                          True               Iztok Arčon
# 2834                          True             Alenka Franko
# 644                           True                M Lainscak
# 426                           True                Tomaž Apih
# 6467                          True                 Marko Noc
# 8104                          True             Klemen Jerina
#
#                   INSTITUTIONS
# 3279                    UNI_LJ
# 6549                    UNI_LJ
# 5162                    UNI_LJ
# 8105                    UNI_LJ
# 8468                    UNI_LJ
# 2309                    UNI_LJ
# 2212                    UNI_LJ
# 5600                    UNI_LJ
# 4884              OTHER,UNI_LJ
# 5867                    UNI_LJ
# 4706              OTHER,UNI_LJ
# 6236                    UNI_LJ
# 580               UNI_LJ,OTHER
# 4081                    UNI_LJ
# 2426                    UNI_LJ
# 210                     UNI_LJ
# 7243                    UNI_LJ
# 2978                    UNI_LJ
# 1455           OTHER,GU,UNI_LJ
# 2170              OTHER,UNI_LJ
# 5368                    UNI_LJ
# 2767                UNI_LJ,n/a
# 4401                    UNI_LJ
# 3075              OTHER,UNI_LJ
# 1312              OTHER,UNI_LJ
# 1444              UNI_LJ,OTHER
# 559               OTHER,UNI_LJ
# 5                 OTHER,UNI_LJ
# 382               UNI_LJ,OTHER
# 1518                    UNI_LJ
# 6194  VUB,OTHER,WARWICK,UNI_LJ
# 1989       OTHER,GU,UNI_LJ,VUB
# 5261              UNI_LJ,OTHER
# 6566              OTHER,UNI_LJ
# 6784              OTHER,UNI_LJ
# 2657                    UNI_LJ
# 6395              OTHER,UNI_LJ
# 4736                    UNI_LJ
# 2837                    UNI_LJ
# 2441      OTHER,WARWICK,UNI_LJ
# 8511              UNI_LJ,OTHER
# 3139      OTHER,WARWICK,UNI_LJ
# 5808                    UNI_LJ
# 5657                    UNI_LJ
# 7096          OTHER,n/a,UNI_LJ
# 602                     UNI_LJ
# 6226                    UNI_LJ
# 5114              UNI_LJ,OTHER
# 4428                    UNI_LJ
# 8436                    UNI_LJ
# 7866                    UNI_LJ
# 4831              OTHER,UNI_LJ
# 5248           OTHER,GU,UNI_LJ
# 5265              UNI_LJ,OTHER
# 6470                    UNI_LJ
# 5232                    UNI_LJ
# 4067              OTHER,UNI_LJ
# 3902          OTHER,UNL,UNI_LJ
# 7414          OTHER,n/a,UNI_LJ
# 3702              UNI_LJ,OTHER
# 6048                    UNI_LJ
# 3639                    UNI_LJ
# 5092                    UNI_LJ
# 2673              OTHER,UNI_LJ
# 6585              OTHER,UNI_LJ
# 7503              OTHER,UNI_LJ
# 6909              UNI_LJ,OTHER
# 5123              UNI_LJ,OTHER
# 1950          OTHER,UNI_LJ,n/a
# 3180              OTHER,UNI_LJ
# 4075           OTHER,GU,UNI_LJ
# 6656                    UNI_LJ
# 7371                    UNI_LJ
# 2742                    UNI_LJ
# 8342                    UNI_LJ
# 5899              OTHER,UNI_LJ
# 310               UNI_LJ,OTHER
# 5885              UNI_LJ,OTHER
# 6181                    UNI_LJ
# 5822          UNI_LJ,n/a,OTHER
# 3822              OTHER,UNI_LJ
# 3776              UNI_LJ,OTHER
# 393                     UNI_LJ
# 420                     UNI_LJ
# 8004                    UNI_LJ
# 4538              OTHER,UNI_LJ
# 3659              UNI_LJ,OTHER
# 262               UNI_LJ,OTHER
# 300                     UNI_LJ
# 6537              OTHER,UNI_LJ
# 3093                    UNI_LJ
# 7881              UNI_LJ,OTHER
# 8012              UNI_LJ,OTHER
# 4866                    UNI_LJ
# 6634              OTHER,UNI_LJ
# 2834                    UNI_LJ
# 644           OTHER,n/a,UNI_LJ
# 426               OTHER,UNI_LJ
# 6467              OTHER,UNI_LJ
# 8104                    UNI_LJ

# %%
# Turn to lowercase
authors['AUTHOR_FULL_NAME_LOWER'] = authors['AUTHOR_FULL_NAME'].str.lower()
# Show authors with the last name 'zupan'
authors[authors['AUTHOR_FULL_NAME_LOWER'].str.contains('zupan')]
# Out:
#                             AUTHOR_SID  PUBLICATIONS  EXTERNAL_COLLABORATIONS  \
# 145   abbde464317710581886a3b405b50c87            21                       14
# 7023  0517f1ec4ceacc10a83f7d1897643225            21                       12
# 8693  735e3e19ac89a3bb0e2dae9c92423f11            22                        1
# 8937  676b85b1d5300255138cd8ccf34fdfec            10                        4
#
#       COLLABORATION_RATE  COLLABORATION_RATE_PERCENTILE  \
# 145             0.666667                        27.0875
# 7023            0.571429                        22.2875
# 8693            0.045455                         2.0250
# 8937                 0.4                        14.8750
#
#       IS_AUTHOR_MORE_COLLABORATIVE AUTHOR_FULL_NAME  INSTITUTIONS  \
# 145                          False    Maja Zupančič        UNI_LJ
# 7023                         False       Blaž Zupan  OTHER,UNI_LJ
# 8693                         False      Marko Zupan        UNI_LJ
# 8937                         False      Eva Zupanic  UNI_LJ,OTHER
#
#      AUTHOR_FULL_NAME_LOWER
# 145           maja zupančič
# 7023             blaž zupan
# 8693            marko zupan
# 8937            eva zupanic
